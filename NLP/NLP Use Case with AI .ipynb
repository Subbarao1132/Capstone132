# %%
import pandas as pd
import nltk as tk
import spacy as sp

# %%
with open("metamorphism.txt", 'r') as myfile:
  txt = myfile.read()

# %%
print (txt)
# Out:
# One morning, when Gregor Samsa woke from troubled dreams, he found
# himself transformed in his bed into a horrible vermin.  He lay on
# his armour-like back, and if he lifted his head a little he could
# see his brown belly, slightly domed and divided by arches into stiff
# sections.  The bedding was hardly able to cover it and seemed ready
# to slide off any moment.  His many legs, pitifully thin compared
# with the size of the rest of him, waved about helplessly as he
# looked.
#
# "What's happened to me?" he thought.  It wasn't a dream.  His room,
# a proper human room although a little too small, lay peacefully
# between its four familiar walls.  A collection of textile samples
# lay spread out on the table - Samsa was a travelling salesman - and
# above it there hung a picture that he had recently cut out of an
# illustrated magazine and housed in a nice, gilded frame.  It showed
# a lady fitted out with a fur hat and fur boa who sat upright,
# ...

# %%
from nltk import word_tokenize

# %%
tk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
low = word_tokenize(txt) 
len(low)
# Out:
# 24937

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
punc_table = str.maketrans("","",string.punctuation)

# %%
txt.translate(punc_table)
# Out:
# 'One morning when Gregor Samsa woke from troubled dreams he found\nhimself transformed in his bed into a horrible vermin  He lay on\nhis armourlike back and if he lifted his head a little he could\nsee his brown belly slightly domed and divided by arches into stiff\nsections  The bedding was hardly able to cover it and seemed ready\nto slide off any moment  His many legs pitifully thin compared\nwith the size of the rest of him waved about helplessly as he\nlooked\n\nWhats happened to me he thought  It wasnt a dream  His room\na proper human room although a little too small lay peacefully\nbetween its four familiar walls  A collection of textile samples\nlay spread out on the table  Samsa was a travelling salesman  and\nabove it there hung a picture that he had recently cut out of an\nillustrated magazine and housed in a nice gilded frame  It showed\na lady fitted out with a fur hat and fur boa who sat upright\nraising a heavy fur muff that covered the whole of her lower arm\ntowards
# ...

# %%
cleaned_txt = txt.translate(punc_table).replace('\n'," ")

# %%
cleaned_low = word_tokenize(cleaned_txt)

# %%
len(cleaned_low)
# Out:
# 22010

# %%
from nltk.corpus import stopwords

# %%
tk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
non_stopwords_low = [word for word in cleaned_low if word.lower() not in stopwords.words('english')]

# %%
len(non_stopwords_low)
# Out:
# 10148

# %%
from nltk import FreqDist

# %%
fd = FreqDist(non_stopwords_low)

# %%
fd.most_common(10)
# Out:
# [('Gregor', 199),
#  ('would', 184),
#  ('room', 131),
#  ('could', 119),
#  ('Gregors', 99),
#  ('sister', 96),
#  ('father', 93),
#  ('door', 87),
#  ('back', 82),
#  ('mother', 79)]

# %%
fd.plot()

# %%
len(fd.most_common())
# Out:
# 2572

# %%
len(set(non_stopwords_low))
# Out:
# 2572

# %%
pl_list = ['python', 'java', 'python', 'java']

# %%
set(pl_list)
# Out:
# {'java', 'python'}

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()

# %%
ps.stem('running')
# Out:
# 'run'

# %%
ps.stem('holding')
# Out:
# 'hold'

# %%
ps.stem('cared')
# Out:
# 'care'

# %%
ps.stem('bittered')
# Out:
# 'bitter'

# %%
ps.stem('losses')
# Out:
# 'loss'

# %%
ps.stem('movements')
# Out:
# 'movement'

# %%
ps.stem('microcomputer')
# Out:
# 'microcomput'

# %%
from nltk.stem import WordNetLemmatizer

# %%
wl = WordNetLemmatizer()

# %%
tk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
wl.lemmatize('ran', pos = 'v')
# Out:
# 'run'

# %%
wl.lemmatize('fishing', pos = 'v')
# Out:
# 'fish'

# %%
wl.lemmatize('ran', pos = 'v')
# Out:
# 'run'

# %%
[wl.lemmatize(word) for word in non_stopwords_low]
# Out:
# ['One',
#  'morning',
#  'Gregor',
#  'Samsa',
#  'woke',
#  'troubled',
#  'dream',
#  'found',
#  'transformed',
#  'bed',
#  'horrible',
#  'vermin',
#  'lay',
#  'armourlike',
#  'back',
#  'lifted',
#  'head',
#  'little',
#  'could',
#  'see',
#  'brown',
#  'belly',
#  'slightly',
#  'domed',
#  'divided',
#  'arch',
#  'stiff',
#  'section',
#  'bedding',
#  'hardly',
#  'able',
#  'cover',
#  'seemed',
#  'ready',
#  'slide',
#  'moment',
#  'many',
#  'leg',
#  'pitifully',
#  'thin',
#  'compared',
#  'size',
#  'rest',
#  'waved',
#  'helplessly',
#  'looked',
#  'Whats',
#  'happened',
#  'thought',
#  'wasnt',
#  'dream',
#  'room',
#  'proper',
#  'human',
#  'room',
#  'although',
#  'little',
#  'small',
#  'lay',
#  'peacefully',
#  'four',
#  'familiar',
#  'wall',
#  'collection',
#  'textile',
#  'sample',
#  'lay',
#  'spread',
#  'table',
#  'Samsa',
#  'travelling',
#  'salesman',
#  'hung',
#  'picture',
#  'recently',
#  'cut',
#  'illustrated',
# ...

# %%
from nltk import pos_tag
from nltk.corpus import wordnet

# %%
tk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
pos_tag(['better'])
# Out:
# [('better', 'RBR')]

# %%
wl.lemmatize('better', pos = wordnet.ADJ)
# Out:
# 'good'

# %%
wl.lemmatize('best', pos = wordnet.ADJ)
# Out:
# 'best'

# %%
# spacy --

# %%
txt = """(CNN)Joe Biden is the President-elect, CNN projected Saturday morning, winning on a message of unity and a pledge to restore the "soul of the nation" after four years of tumult under President Donald Trump.

Biden rebuilt the "blue wall" of Great Lakes states where Trump had won four years earlier. He also delivered Democrats' strongest performance in a generation in Arizona and Georgia, leading both states by narrow margins as votes continue to be counted there and in Nevada, where CNN projects a Biden victory.
Biden, who turns 78 later this month and who was among the youngest men ever elected to the Senate in 1972, is now the oldest elected to the presidency.
In his third bid for the presidency, Biden's life story of overcoming personal tragedy met the moment of a nation in the grips of health and economic crises. He built a coalition of people of color, suburban women, younger and older voters, and just enough independents and disaffected Republicans to win narrow margins in several battleground states where Republicans down-ballot outperformed Trump."""

# %%
print(txt)
# Out:
# (CNN)Joe Biden is the President-elect, CNN projected Saturday morning, winning on a message of unity and a pledge to restore the "soul of the nation" after four years of tumult under President Donald Trump.
#
# Biden rebuilt the "blue wall" of Great Lakes states where Trump had won four years earlier. He also delivered Democrats' strongest performance in a generation in Arizona and Georgia, leading both states by narrow margins as votes continue to be counted there and in Nevada, where CNN projects a Biden victory.
# Biden, who turns 78 later this month and who was among the youngest men ever elected to the Senate in 1972, is now the oldest elected to the presidency.
# ...

# %%
nlp = sp.load('en')
doc = nlp(txt)

# %%
print(doc)
# Out:
# (CNN)Joe Biden is the President-elect, CNN projected Saturday morning, winning on a message of unity and a pledge to restore the "soul of the nation" after four years of tumult under President Donald Trump.
#
# Biden rebuilt the "blue wall" of Great Lakes states where Trump had won four years earlier. He also delivered Democrats' strongest performance in a generation in Arizona and Georgia, leading both states by narrow margins as votes continue to be counted there and in Nevada, where CNN projects a Biden victory.
# Biden, who turns 78 later this month and who was among the youngest men ever elected to the Senate in 1972, is now the oldest elected to the presidency.
# ...

# %%
for sentence in doc.sents:
  print(sentence)
# Out:
# (CNN)Joe Biden is the President-elect, CNN projected Saturday morning, winning on a message of unity and a pledge to restore the "soul of the nation" after four years of tumult under President Donald Trump.
#
#
# Biden rebuilt the "blue wall" of Great Lakes states where Trump had won four years earlier.
# He also delivered Democrats' strongest performance in a generation in Arizona and Georgia, leading both states by narrow margins as votes continue to be counted there and in Nevada, where CNN projects a Biden victory.
#
# Biden, who turns 78 later this month and who was among the youngest men ever elected to the Senate in 1972, is now the oldest elected to the presidency.
#
# In his third bid for the presidency, Biden's life story of overcoming personal tragedy met the moment of a nation in the grips of health and economic crises.
# ...

# %%
for word in doc:
  print(word)
# Out:
# (
# CNN)Joe
# Biden
# is
# the
# President
# -
# elect
# ,
# CNN
# projected
# Saturday
# morning
# ,
# winning
# on
# a
# message
# of
# unity
# and
# a
# pledge
# to
# restore
# the
# "
# soul
# of
# the
# nation
# "
# after
# four
# years
# of
# tumult
# under
# President
# Donald
# Trump
# .
#
#
#
# Biden
# rebuilt
# the
# "
# blue
# wall
# "
# of
# Great
# Lakes
# states
# where
# Trump
# had
# won
# four
# years
# earlier
# .
# He
# also
# delivered
# Democrats
# '
# strongest
# performance
# in
# a
# generation
# in
# Arizona
# and
# Georgia
# ,
# leading
# both
# states
# by
# narrow
# margins
# as
# votes
# continue
# to
# be
# counted
# there
# and
# in
# Nevada
# ,
# where
# CNN
# projects
# a
# Biden
# victory
# .
#
#
# Biden
# ,
# who
# turns
# 78
# later
# this
# month
# and
# who
# was
# among
# the
# youngest
# men
# ever
# elected
# to
# the
# Senate
# in
# 1972
# ,
# is
# now
# the
# oldest
# elected
# to
# the
# presidency
# .
#
#
# In
# his
# third
# bid
# for
# ...

# %%
for word in doc:
  print(word,word.is_stop, word.is_punct, word.is_quote)
# Out:
# ( False True False
# CNN)Joe False False False
# Biden False False False
# is True False False
# the True False False
# President False False False
# - False True False
# elect False False False
# , False True False
# CNN False False False
# projected False False False
# Saturday False False False
# morning False False False
# , False True False
# winning False False False
# on True False False
# a True False False
# message False False False
# of True False False
# unity False False False
# and True False False
# a True False False
# pledge False False False
# to True False False
# restore False False False
# the True False False
# " False True True
# soul False False False
# of True False False
# the True False False
# nation False False False
# " False True True
# after True False False
# four True False False
# years False False False
# of True False False
# tumult False False False
# under True False False
# President False False False
# Donald False False False
# ...

# %%
for ent in doc.ents:
  print(ent.text, ent.label_)
# Out:
# Biden PERSON
# CNN ORG
# Saturday DATE
# morning TIME
# four years DATE
# Donald Trump PERSON
# Great Lakes GPE
# Trump PERSON
# four years earlier DATE
# Democrats NORP
# Arizona GPE
# Georgia GPE
# Nevada GPE
# CNN ORG
# Biden NORP
# 78 later this month DATE
# Senate ORG
# 1972 DATE
# third ORDINAL
# Biden PERSON
# Republicans NORP
# Republicans NORP
# Trump PRODUCT

# %%
from spacy import displacy

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">(CNN)Joe
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is the President-elect,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  projected
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saturday
# ...

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1b01203ee5454f1fa5adacf1f9711963-0" class="displacy" width="32075" height="1274.5" direction="ltr" style="max-width: none; height: 1274.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">(</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">CNN)Joe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
# ...
